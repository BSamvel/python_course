# %%
# Subscripting
print("Hello"[0])
print("Hello"[-1])
# Out:
# H
# o

# %%
# String
print("123" + "345")
# Out:
# 123345

# %%
# Integer = Whole number
print(123 + 345)
# Out:
# 468

# %%
# Large Integers
print(123_456_789)
# Out:
# 123456789

# %%
# Float = Floating Point Number
print(3.14159)
# Out:
# 3.14159

# %%
# Boolean
print(True)
print(False)
# Out:
# True
# False

# %%
len("Hello")
print(type("Hello"))
# Out:
# <class 'str'>

# %%
print(type(123), type(23.23), type(False), type("abc"))
# Out:
# <class 'int'> <class 'float'> <class 'bool'> <class 'str'>

# %%
print("123" + "456")
print(int("123") + int("456"))
# Out:
# 123456
# 579

# %%
print("Number of letter in your name: " + str(len(input("Enter your name"))))
# Out:
# Number of letter in your name: 6

# %%
name_of_the_user = input("Enter your name")
length_of_name = len(name_of_the_user)

print(type("Number of letters in your name: "))
print(type(length_of_name))

print("Numbe of letters in your name:  " + str(length_of_name))
# Out:
# <class 'str'>
# <class 'int'>
# Numbe of letters in your name:  3

# %%
print("My age: " + str(12))
print(123 + 456)
print(7 - 3)
print(3 * 2)
print(5 / 3)
print(5 // 3)
print(2**3)
# Out:
# My age: 12
# 579
# 4
# 6
# 1.6666666666666667
# 1
# 8

# %%
print(3 * 3 + 3 / 3 - 3)
print(3 * (3 + 3) / 3 - 3)
# Out:
# 7.0
# 3.0

# %%
bmi = 84 / 1.65 ** 2

print(bmi)

print(int(bmi))

print(round(bmi))

print(round(bmi, 2))
# Out:
# 30.85399449035813
# 30
# 31
# 30.85

# %%
score = 0

# User scores a point
score += 1
print(score)

# f-strings
print("Your score is " + str(score))
# Out:
# 1
# Your score is 1

# %%
score = 0
height = 1.8
is_wining = True

print(f"Your score is = {score}, your height is {height}, You are wining is {is_wining}")
# Out:
# Your score is = 0, your height is 1.8, You are wining is True

# %%
print("Welcome to the tip calculator")
bill = float(input("What was the total bill?"))
tip = int(input("How much tip would you like to give? 10, 12 or 15?"))
people = int(input("How many people to split the bill?"))
tip_as_percent = tip / 100
total_tip_amount = bill * tip_as_percent
total_bill = bill + tip_as_percent
bill_per_person = total_bill / people
final_amount = round(bill_per_person, 2)
print(f"Each person should pay: ${final_amount}")
# Out:
# Welcome to the tip calculator
# Each person should pay: $30.72
