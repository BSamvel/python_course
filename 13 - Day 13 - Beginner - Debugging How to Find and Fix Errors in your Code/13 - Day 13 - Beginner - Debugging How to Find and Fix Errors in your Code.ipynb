# %%
def my_function():
    for i in range(1, 20):
        if i == 20:
            print("You got it")

my_function()

# Describe the Problem - Write your answers as comments:
# 1. What is the for loop doing?
# 2. When is the function meant to print "You got it"?
# 3. What are your assumptions about the value of i?
# Out:
# You got it

# %%
# Fix the bug
from random import randint

dice_images = ["1", "2", "3", "4", "5", "6"]
dice_num = randint(1, 6)
print(dice_images[dice_num])
# Out:
# 4

# %%
# Fix the bug
year = int(input("What;s your year of birth?"))

if year > 1980 and year < 1994:
    print("You are a millennial.")
elif year > 1994:
    print("You are a Gen Z.")
# Out:
# You are a Gen Z.

# %%
try:
    age = int(input("How old are you?"))
except ValueError:
    print("You have types in a an invalid number. Please try again with a numberical response such as 15")
    age = int(input("How old are you?"))

if age > 18:
    print(f"You can drive at {age}.")
# Out:
# You have types in a an invalid number. Please try again with a numberical response such as 15
# You can drive at 20.

# %%
# Always use print it is your best friend :d
word_per_page = 0
pages = int(input("Number of pages: "))
word_per_page = int(input("Number of words per page: "))
total_words = pages * word_per_page

print(f"pages = {pages}")
print(f"Words_per_page = {word_per_page}")
print(total_words)
# Out:
# pages = 45
# Words_per_page = 250
# 11250

# %%
# Debuger
import random
import maths

def mutate(a_list):
    b_list = []
    new_item = 0
    for item in a_list:
        new_item = item * 2
        new_item += random.randint(1, 3)
        new_item = maths.add(new_item, item)
        b_list.append(new_item)
    print(b_list)

mutate([1, 2, 3, 5, 8, 13])
# Out:
# [6, 7, 10, 17, 25, 42]
