# %%
def format_name(f_name, l_name):
    formated_name = f_name.title()
    formated_l_name = l_name.title()

    return f"{formated_name} {formated_l_name}"

formated_string = format_name("ANgeLa", "yU")
print(formated_string)
#or
print(format_name("ANgeLa", "yU"))

# output = len("Angela")
# print(output)
# Out:
# Angela Yu
# Angela Yu

# %%
def function_1(text):
    return text + text

def function_2(text):
    return text.title()

output = function_2(function_1("hello "))
print(output)
# Out:
# Hello Hello

# %%
def format_name(f_name, l_name):
    #here is a docstring
    """Take a first and last name and format it to return the 
    title case version ot the name."""
    if f_name == "" or l_name == "":
        return "You did not provide valid inputs"
    formated_name = f_name.title()
    formated_l_name = l_name.title()

    return f"Result: {formated_name} {formated_l_name}"

print(format_name(input("What is your first name?"), input("What is your last name?")))
# Out:
# You did not provide valid inputs

# %%
# Finnal Project - Calculator
import art

# TODO:1 Write out the other 3 functions - subtract, multiply and divide.

def add(n1, n2):
    return n1 + n2

def subtract(n1, n2):
    return n1 - n2

def multiply(n1, n2):
    return n1 * n2

def divide(n1, n2):
    return n1 / n2


# TODO:2 Add these 4 function into a dictionray as the values. "+", "-", "*", "/"

operations = {
    "+": add,
    "-": subtract,
    "*": multiply,
    "/": divide
}

# TODO:3 Use the dictionary operatiosn to perform the calculations. Multiply 4 * 8 using the dictionary.
# print(operations["*"](4, 8))

def calculator():
    print(art.logo)
    num1 = float(input("What is the first number?: "))
    should_accumulate = True

    while should_accumulate:
        for symbol in operations:
            print(symbol)
        operation_symbol = input("Pick an operation: ")
        num2 = float(input("What is the next number?: "))

        answer = operations[operation_symbol](num1, num2)
        print(f"{num1} {operation_symbol} {num2} = {answer}")

        choice = input(f"Type 'y' to continue calculating with {answer}, or type 'n' to start a new calculation: ").lower()

        if choice == "y":
            num1 = answer
        else:
            should_accumulate = False
            print("\n" * 33)
            calculator()

calculator()
# Out:
#      _____________________
# |  _________________  |
# | | JO           0. | |
# | |_________________| |
# |  ___ ___ ___   ___  |
# | | 7 | 8 | 9 | | + | |
# | |___|___|___| |___| |
# | | 4 | 5 | 6 | | - | |
# | |___|___|___| |___| |
# | | 1 | 2 | 3 | | x | |
# | |___|___|___| |___| |
# | | . | 0 | = | | / | |
# | |___|___|___| |___| |
# |_____________________|
#          _            _       _
#           | |          | |     | |
#   ___ __ _| | ___ _   _| | __ _| |_ ___  _ __
#  / __/ _` | |/ __| | | | |/ _` | __/ _ \| '__|
# | (_| (_| | | (__| |_| | | (_| | || (_) | |
#  \___\__,_|_|\___|\__,_|_|\__,_|\__\___/|_|
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[31], line 54
#      51             print("\n" * 33)
#      52             calculator()
# ---> 54 calculator()
#
# Cell In[31], line 33, in calculator()
#      31 def calculator():
# ...
