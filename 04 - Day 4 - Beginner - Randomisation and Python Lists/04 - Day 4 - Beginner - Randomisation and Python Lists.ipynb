# %%
import random
import my_module

random_integer = random.randint(1, 10)
print(random_integer)

print(my_module.my_favorite_number)
# Out:
# 4
# 3.1415

# %%
import random

# random_number_0_to_1 = random.random() * 10
# print(random_number_0_to_1)

random_float = random.uniform(1, 10)
print(random_float)
# Out:
# 4.977534510325153

# %%
import random

random_heads_or_tails = random.randint(0, 1)
if random_heads_or_tails == 0:
    print("Heads")
else:
    print("Tails")
# Out:
# Tails

# %%
states_of_america = ["Delaware", "Pennsylvania", "New Jersey", "Georgia", "Arizona", "Alaska", "Hawaii"]

print(states_of_america[-2])
# Out:
# Alaska

# %%
states_of_america[1] = "Pencilvania"
print(states_of_america)
# Out:
# ['Delaware', 'Pencilvania', 'New Jersey', 'Georgia', 'Arizona', 'Alaska', 'Hawaii']

# %%
states_of_america.append("Angelaland")
print(states_of_america)
# Out:
# ['Delaware', 'Pencilvania', 'New Jersey', 'Georgia', 'Arizona', 'Alaska', 'Hawaii', 'Angelaland', 'Angelaland']

# %%
states_of_america.extend(["Angelaland", "Jack Bauer Land"])
print(states_of_america)
# Out:
# ['Delaware', 'Pencilvania', 'New Jersey', 'Georgia', 'Arizona', 'Alaska', 'Hawaii', 'Angelaland', 'Angelaland', 'Angelaland', 'Jack Bauer Land']

# %%
import random

friends = ["Alice", "Bob", "Charlie", "David", "Emanuel"]

# 1 Option
print(random.choice(friends))

# 2nd Option
random_index = random.randint(0, 4)
print(friends[random_index])
# Out:
# Emanuel
# Bob

# %%
print(len(states_of_america))

print(states_of_america[10])

num_of_states = len(states_of_america)
print(states_of_america[num_of_states - 1])
# Out:
# 11
# Jack Bauer Land
# Jack Bauer Land

# %%
# dirty_dozen = ["Strawberies", "Spinach", "Kale", "Nectarines", "Apples", "Grap", "Cherries", "Peaches", "Pear"]

fruits = ["Strawberries", "Nectarines", "Apples", "Grapes", "Peaches", "Cherries", "Pear"]
vegetables = ["Spinach", "Kale", "Tomatoes", "Celery", "Potatoes"]

dirty_dozen = [fruits, vegetables]
print(dirty_dozen)
# Out:
# [['Strawberries', 'Nectarines', 'Apples', 'Grapes', 'Peaches', 'Cherries', 'Pear'], ['Spinach', 'Kale', 'Tomatoes', 'Celery', 'Potatoes']]

# %%
rock = '''
                  _    
               | |   
 _ __ ___   ___| | __
| '__/ _ \ / __| |/ /
| | | (_) | (__|   < 
|_|  \___/ \___|_|\_\
'''

paper = '''
     _ __   __ _ _ __   ___ _ __ 
| '_ \ / _` | '_ \ / _ \ '__|
| |_) | (_| | |_) |  __/ |   
| .__/ \__,_| .__/ \___|_|   
| |         | |              
|_|         |_|     
'''

scissors = '''
  ____
  / __ \
 ( (__) |___ ___
  \________,'   """""----....____
   _______<  () dd       ____----'
  / __   __`.___-----""""
 ( (__) |
  \____/
'''

random_choise = random.choice(game_cards)
choose = int(input("What do you choose? Type 0 for Rock 1 for Paper or 2 for Scissors. "))
game_cards = [rock, paper, scissors]

if choose == 0:
    print(rock)
elif choose == 1:
    print(paper)
elif choose == 2:
    print(scissors)
else:
    print("You enterd wrong number")

print("Computer chose: ")
print(random_choise)

if choose == 0 and random_choise == 1:
    print("Computer win")
elif choose == 1 and random_choise == 2:
    print("Computer win")
elif choose == 2 and random_choise == 0:
    print("Computer win")
elif (choose == 0 and random_choise == 0) or (choose == 1 and random_choise == 1) or (choose == 2 and random_choise == 2):
    print("Try again here is a equal fight")
else:
    print("You win")
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\ '
# <>:10: SyntaxWarning: invalid escape sequence '\ '
# <>:19: SyntaxWarning: invalid escape sequence '\_'
# <>:1: SyntaxWarning: invalid escape sequence '\ '
# <>:10: SyntaxWarning: invalid escape sequence '\ '
# <>:19: SyntaxWarning: invalid escape sequence '\_'
# C:\Users\SamBa\AppData\Local\Temp\ipykernel_37624\3251158621.py:1: SyntaxWarning: invalid escape sequence '\ '
#   rock = '''
# C:\Users\SamBa\AppData\Local\Temp\ipykernel_37624\3251158621.py:10: SyntaxWarning: invalid escape sequence '\ '
#   paper = '''
# C:\Users\SamBa\AppData\Local\Temp\ipykernel_37624\3251158621.py:19: SyntaxWarning: invalid escape sequence '\_'
#   scissors = '''
#                   _
#                | |
#  _ __ ___   ___| | __
# | '__/ _ \ / __| |/ /
# | | | (_) | (__|   <
# |_|  \___/ \___|_|\_
# Computer chose:
#
#                   _
#                | |
#  _ __ ___   ___| | __
# | '__/ _ \ / __| |/ /
# | | | (_) | (__|   <
# ...

# %%
import random
rock = '''
                  _    
               | |   
 _ __ ___   ___| | __
| '__/ _ \ / __| |/ /
| | | (_) | (__|   < 
|_|  \___/ \___|_|\_\
'''

paper = '''
     _ __   __ _ _ __   ___ _ __ 
| '_ \ / _` | '_ \ / _ \ '__|
| |_) | (_| | |_) |  __/ |   
| .__/ \__,_| .__/ \___|_|   
| |         | |              
|_|         |_|     
'''

scissors = '''
  ____
  / __ \
 ( (__) |___ ___
  \________,'   """""----....____
   _______<  () dd       ____----'
  / __   __`.___-----""""
 ( (__) |
  \____/
'''

game_images = [rock, paper, scissors]

user_choice = int(input("What do you choose? Type 0 for Rock 1 for Paper or 2 for Scissors. \n"))
if user_choice >= 0 and user_choice <= 2:
    print(game_images[user_choice])


computer_choice = random.randint(0, 2)
print("Computer chose")
print(game_images[computer_choice])

if user_choice >= 3 or user_choice < 0:
    print("You typed an invalid number. You lose! ")
elif user_choice == 0 and computer_choice == 2:
    print("you win!")
elif computer_choice == 0 and user_choice == 2:
    print("You lose!") 
elif computer_choice > user_choice:
    print("You lose!")
elif user_choice > computer_choice:
    print("You win!")
elif computer_choice == user_choice: 
    print("It's a draw")
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\ '
# <>:11: SyntaxWarning: invalid escape sequence '\ '
# <>:20: SyntaxWarning: invalid escape sequence '\_'
# <>:2: SyntaxWarning: invalid escape sequence '\ '
# <>:11: SyntaxWarning: invalid escape sequence '\ '
# <>:20: SyntaxWarning: invalid escape sequence '\_'
# C:\Users\SamBa\AppData\Local\Temp\ipykernel_99916\2533424744.py:2: SyntaxWarning: invalid escape sequence '\ '
#   rock = '''
# C:\Users\SamBa\AppData\Local\Temp\ipykernel_99916\2533424744.py:11: SyntaxWarning: invalid escape sequence '\ '
#   paper = '''
# C:\Users\SamBa\AppData\Local\Temp\ipykernel_99916\2533424744.py:20: SyntaxWarning: invalid escape sequence '\_'
#   scissors = '''
#      _ __   __ _ _ __   ___ _ __
# | '_ \ / _` | '_ \ / _ \ '__|
# | |_) | (_| | |_) |  __/ |
# | .__/ \__,_| .__/ \___|_|
# | |         | |
# |_|         |_|
#
# Computer chose
#
#   ____
#   / __  ( (__) |___ ___
#   \________,'   """""----....____
#    _______<  () dd       ____----'
# ...
