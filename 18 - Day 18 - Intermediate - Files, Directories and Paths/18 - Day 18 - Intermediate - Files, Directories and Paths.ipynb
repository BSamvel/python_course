# %%
file = open("my_file.txt")
contents = file.read()
print(contents)
file.close()
# Out:
# Hello, My dear, How are you?

# %%
with open("my_file.txt") as file:
    contents = file.read()
    print(contents)
# Out:
# Hello, My dear, How are you?

# %%
with open("my_file.txt", mode="a") as file:
    file.write("\nNew text.")

# %%
with open("my_file.txt") as file:
    contents = file.read()
    print(contents)

with open("new_file.txt", mode="w") as file:
    file.write("New text.")
# Out:
# Hello My dear, How are you?New text.
# New text.
